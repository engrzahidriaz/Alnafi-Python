# %%
# Numbers
Allah_names = 99

# %%
Allah_names
# Out:
# 99

# %%
Allah names
# Out:
#   File "<ipython-input-3-ed172028117a>", line 1
#     Allah names
#               ^
# SyntaxError: invalid syntax

# %%
Zahid_Riaz = 50

# %%
Zahid Riaz = 50
# Out:
#   File "<ipython-input-5-9a4e0bd9b6e9>", line 1
#     Zahid Riaz = 50
#              ^
# SyntaxError: invalid syntax

# %%
alnafi_portal = 1
alnafi_portal = ["cissp" , "oscp"]

# %%
alnafi_portal
# Out:
# ['cissp', 'oscp']

# %%
a = 10

# %%
b = 10.5

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
Ali_sibling = 4
Umar_sibling = 3
total = Ali_sibling + Umar_sibling

# %%
total
# Out:
# 7

# %%
#string 
"hello"
# Out:
# 'hello'

# %%
'hello'
# Out:
# 'hello'

# %%
["hello"]
# Out:
# ['hello']

# %%
'Islam is the religion of Peace'
# Out:
# 'Islam is the religion of Peace'

# %%
"Islam is the religion of Peace"
# Out:
# 'Islam is the religion of Peace'

# %%
'it's is my book'
# Out:
#   File "<ipython-input-7-03c4b648f065>", line 1
#     'it's is my book'
#         ^
# SyntaxError: invalid syntax

# %%
"it's is my book"
# Out:
# "it's is my book"

# %%
print("it's my book")
# Out:
# it's my book

# %%
"hello"
"Zahid"
# Out:
# 'Zahid'

# %%
print("hello")
print("zahid")
# Out:
# hello
# zahid

# %%
print("hello \n zahid")
# Out:
# hello
#  zahid

# %%
print("hello \t zahid")
# Out:
# hello 	 zahid

# %%
len("zahid")
# Out:
# 5

# %%
len("zahid riaz")
# Out:
# 10

# %%
mystring = "my name is Abdul-Hadi"

# %%
mystring
# Out:
# 'my name is Abdul-Hadi'

# %%
mystring[1]
# Out:
# 'y'

# %%
mystring[2]
# Out:
# ' '

# %%
mystring[8]
# Out:
# 'i'

# %%
mystring[2:6]
# Out:
# ' nam'

# %%
mystring[-2]
# Out:
# 'd'

# %%
mystring[-10]
# Out:
# 'A'

# %%
mystring[11:16]
# Out:
# 'Abdul'

# %%
mystring[2:]
# Out:
# ' name is Abdul-Hadi'

# %%
mystring[:2]
# Out:
# 'my'

# %%
mystring[::]
# Out:
# 'my name is Abdul-Hadi'

# %%
mystring[::2]
# Out:
# 'm aei bu-ai'

# %%
new_string = "zahid Riaz"
new_string
# Out:
# 'zahid Riaz'

# %%
new_string[::2]
# Out:
# 'zhdRa'

# %%
new_string[::3]
# Out:
# 'ziRz'

# %%
new_string[2:2:2]
# Out:
# ''

# %%
new_string[1:2:9]
# Out:
# 'a'

# %%
mystring[2:3:11]
# Out:
# ' '

# %%
new_string[1:9:2]
# Out:
# 'ai i'

# %%
mystring[3:17:3]
# Out:
# 'nesbl'

# %%
new_string[::-1]
# Out:
# 'zaiR dihaz'

# %%
new_string[::-2]
# Out:
# 'zi ia'

# %%
name = "usman"

# %%
name[0] = "I"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-1cf50eaa6030> in <module>
# ----> 1 name[0] = "I"
#
# TypeError: 'str' object does not support item assignment

# %%
name = ["usman"]
name[0] = "I"

# %%
name
# Out:
# ['I']

# %%
name[0] = "I" #immutable

# %%
new_name = "Bablo"
new_name
# Out:
# 'Bablo'

# %%
last_letter = new_name[0:4]

# %%
last_letter
# Out:
# 'Babl'

# %%
last_letter + "i"
# Out:
# 'Babli'

# %%
a = "salam"

# %%
a + " mean peace"
# Out:
# 'salam mean peace'

# %%
a = "salam"
a = a + " mean peace"

# %%
a
# Out:
# 'salam mean peace'

# %%
child = "Abdul Hadi"
child*3
# Out:
# 'Abdul HadiAbdul HadiAbdul Hadi'

# %%
Hadi*3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-0c757a7e7141> in <module>
# ----> 1 Hadi*3
#
# NameError: name 'Hadi' is not defined

# %%
'Hadi'*3
# Out:
# 'HadiHadiHadi'

# %%
5 + 5
# Out:
# 10

# %%
'5' + '5'
# Out:
# '55'

# %%
xyz = "Abdul-Hadi"
xyz.lower()
# Out:
# 'abdul-hadi'

# %%
xyz = "Abdul-Hadi"
xyz.upper()
# Out:
# 'ABDUL-HADI'

# %%
xyz.lower
# Out:
# <function str.lower()>

# %%
xyz.split()
# Out:
# ['Abdul-Hadi']

# %%
c = 'my name is zahid'

# %%
c.split()
# Out:
# ['my', 'name', 'is', 'zahid']

# %%
c.split(a)
# Out:
# ['my name is zahid']

# %%
c.split('a')
# Out:
# ['my n', 'me is z', 'hid']

# %%
c.split('m')
# Out:
# ['', 'y na', 'e is zahid']

# %%
print('my anme is')
# Out:
# my anme is

# %%
print('my name is {}' .format('Zahid'))
# Out:
# my name is Zahid

# %%
print('my name is {} {}' .format('Zahid','Riaz'))
# Out:
# my name is Zahid Riaz

# %%
print('my name is {0} {1}' .format('Zahid','Riaz'))
# Out:
# my name is Zahid Riaz

# %%
print('my name is {0} {0}' .format('Zahid','Riaz'))
# Out:
# my name is Zahid Zahid

# %%
result = 100/88
result
# Out:
# 1.1363636363636365

# %%
print('the result is {}'.format(result))
# Out:
# the result is 1.1363636363636365

# %%
print('the result is {r}'.format(r=result))
# Out:
# the result is 1.1363636363636365

# %%
print('the result is {r:1.4f}'.format(r=result))
# Out:
# the result is 1.1364

# %%
print('the result is {r:10.4f}'.format(r=result))
# Out:
# the result is     1.1364

# %%
myname = 'zahid'
myname
# Out:
# 'zahid'

# %%
print('hello, I am {}'.format(myname))
# Out:
# hello, I am zahid

# %%
print(f'hello, I am {myname}')
# Out:
# hello, I am zahid

# %%
hello = 'Abdul-Hadi'
age = 1
print(f'{hello} is {age} year old')
# Out:
# Abdul-Hadi is 1 year old

# %%
# method
mylist = [1,2,3,4]

# %%
mylist.append(5)

# %%
mylist
# Out:
# [1, 2, 3, 4, 5]

# %%
mylist.pop(3)
# Out:
# 4

# %%
mylist
# Out:
# [1, 2, 3, 5]

# %%
help(mylist.index)
# Out:
# Help on built-in function index:
#
# index(value, start=0, stop=9223372036854775807, /) method of builtins.list instance
#     Return first index of value.
#
#     Raises ValueError if the value is not present.

# %%
help(mylist.pop)
# Out:
# Help on built-in function pop:
#
# pop(index=-1, /) method of builtins.list instance
#     Remove and return item at index (default last).
#
#     Raises IndexError if list is empty or index is out of range.

# %%
from turtle import *
color('red', 'yellow')
begin_fill()
while True:
    forward(200)
    left(170)
    if abs(pos()) < 1:
        break
end_fill()
done()

# %%
color

# %%
# tuple 
tup = (1,2,3)

# %%
tup
# Out:
# (1, 2, 3)

# %%
list = [1,2,3]

# %%
type(tup)
# Out:
# tuple

# %%
type(list)
# Out:
# list

# %%
len(tup)
# Out:
# 3

# %%
tup1 = ('zahid','riaz','Hadi')

# %%
tup1[2]
# Out:
# 'Hadi'

# %%
tup1[-1]
# Out:
# 'Hadi'

# %%
tup1[-2]
# Out:
# 'riaz'

# %%
tup1.count('riaz')
# Out:
# 1

# %%
tup1.count('python')
# Out:
# 0

# %%
tup1.index('riaz')
# Out:
# 1

# %%
tup1.index('Hadi')
# Out:
# 2

# %%
tup1[2] = "Amjad"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-27b16bc9677c> in <module>
# ----> 1 tup1[2] = "Amjad"
#
# TypeError: 'tuple' object does not support item assignment

# %%
list[2] = 4

# %%
list
# Out:
# [1, 2, 4]

# %%
# set
myset = set()

# %%
myset
# Out:
# set()

# %%
myset.add(1)

# %%
myset
# Out:
# {1}

# %%
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %%
mylist = [1,1,2,2,2,3,3,4,4]

# %%
mylist
# Out:
# [1, 1, 2, 2, 2, 3, 3, 4, 4]

# %%
set(mylist)
# Out:
# {1, 2, 3, 4}

# %%
list2 = [5,5,4,4,4,3,3,2,2]

# %%
set(list2)
# Out:
# {2, 3, 4, 5}

# %%
# boolean
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
4 > 5
# Out:
# False

# %%
9 == 9
# Out:
# True

# %%
a = none
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-862ff12bece4> in <module>
# ----> 1 a = none
#
# NameError: name 'none' is not defined

# %%
a = None

# %%
a

# %%
2 == 2
# Out:
# True

# %%
2 == 5
# Out:
# False

# %%
6 <= 8
# Out:
# True

# %%
6 =< 9
# Out:
#   File "<ipython-input-40-5f31835279c1>", line 1
#     6 =< 9
#        ^
# SyntaxError: invalid syntax

# %%
'salam' == 'salm'
# Out:
# False

# %%
6 <= 6
# Out:
# True

# %%
2 < 5 < 9
# Out:
# True

# %%
2< 5 < 4
# Out:
# False

# %%
1 < 2 and 3 < 5
# Out:
# True

# %%
1 > 2 and 3 < 5
# Out:
# False

# %%
1 < 2 or 3 < 5
# Out:
# True

# %%
1 > 2 or 3 < 5
# Out:
# True

# %%
not 5 == 5
# Out:
# False

# %%
not 5 == 7
# Out:
# True

# %%
# list
my_list = [2,3,4]

# %%
my_list
# Out:
# [2, 3, 4]

# %%
new_list = ['hello',100, 4]

# %%
len(new_list)
# Out:
# 3

# %%
new_list[0]
# Out:
# 'hello'

# %%
new_list[2]
# Out:
# 4

# %%
new_list[0:]
# Out:
# ['hello', 100, 4]

# %%
new_list[1:]
# Out:
# [100, 4]

# %%
new_list[:2]
# Out:
# ['hello', 100]

# %%
my_list + new_list
# Out:
# [2, 3, 4, 'hello', 100, 4]

# %%
second_list = my_list + new_list

# %%
second_list[0] = 'Hadi'

# %%
second_list
# Out:
# ['Hadi', 3, 4, 'hello', 100, 4]

# %%
second_list.append('zahid')

# %%
second_list
# Out:
# ['Hadi', 3, 4, 'hello', 100, 4, 'zahid']

# %%
second_list.pop
# Out:
# <function list.pop(index=-1, /)>

# %%
second_list.pop(4)
# Out:
# 100

# %%
second_list.pop('4')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-e75c08779442> in <module>
# ----> 1 second_list.pop('4')
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
second_list
# Out:
# ['Hadi', 3, 4, 'hello', 4, 'zahid']

# %%
second_list.pop()
# Out:
# 'zahid'

# %%
popped_item = second_list.pop()

# %%
popped_item
# Out:
# 4

# %%
final_list = ['usman','ali','abubakr','umar']

# %%
num_list = [4,3,5,6,1]

# %%
num_list.sort()

# %%
num_list
# Out:
# [1, 3, 4, 5, 6]

# %%
num_list.reverse()

# %%
num_list
# Out:
# [6, 5, 4, 3, 1]

# %%
# Dictionaries
Dict_zahid = {'key1':'value1','key2':'value2'}

# %%
Dict_zahid
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
Dict_zahid['key2']
# Out:
# 'value2'

# %%
prices_lookup = {'pen':2,'pencil':4,'book':5}

# %%
prices_lookup
# Out:
# {'pen': 2, 'pencil': 4, 'book': 5}

# %%
prices_lookup['pen']
# Out:
# 2

# %%
prices_lookup[5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-337a06d339e7> in <module>
# ----> 1 prices_lookup[5]
#
# KeyError: 5

# %%
dic = {'k':245,'l':452,'m':[3,4,5,2],'n':{'a':1,'b':2}}

# %%
dic['k']
# Out:
# 245

# %%
dic['m']
# Out:
# [3, 4, 5, 2]

# %%
dic['n']
# Out:
# {'a': 1, 'b': 2}

# %%
dic['n']['b']
# Out:
# 2

# %%
dic['m'][3]
# Out:
# 2

# %%
my_dict = {'key':['ali','usman','abubakr','umar']}

# %%
my_dict['key'][2]
# Out:
# 'abubakr'

# %%
list1 = my_dict['key']

# %%
list1
# Out:
# ['ali', 'usman', 'abubakr', 'umar']

# %%
name = list1[2]

# %%
name
# Out:
# 'abubakr'

# %%
name.upper()
# Out:
# 'ABUBAKR'

# %%
my_dict['key'][2].upper
# Out:
# <function str.upper()>

# %%
my_dict['key'][2].upper()
# Out:
# 'ABUBAKR'

# %%
my_dict
# Out:
# {'key': ['ali', 'usman', 'abubakr', 'umar']}

# %%
dic2 = {'key1':100,'key2':200,'key':300}

# %%
dic2
# Out:
# {'key1': 100, 'key2': 200, 'key': 300}

# %%
dic2['key3'] = 400

# %%
dic2
# Out:
# {'key1': 100, 'key2': 200, 'key': 300, 'key3': 400}

# %%
dic2['key1'] = 000

# %%
dic2
# Out:
# {'key1': 0, 'key2': 200, 'key': 300, 'key3': 400}

# %%
dic2.keys()
# Out:
# dict_keys(['key1', 'key2', 'key', 'key3'])

# %%
dic2.values()
# Out:
# dict_values([0, 200, 300, 400])

# %%
dic2.items()
# Out:
# dict_items([('key1', 0), ('key2', 200), ('key', 300), ('key3', 400)])

# %%
# If- else
if True:
    print('salam')
# Out:
# salam

# %%
tired = True
if tired:
    print('sleep')
# Out:
# sleep

# %%
tired = False
if tired:
    print('sleep')

# %%
tired = False
if tired:
    print('sleep')
else:
    print('get back to work')
# Out:
# get back to work

# %%
location = 'Masjid'

if location == 'restaurant':
    print('eat')
else:
    print('pray')
# Out:
# pray

# %%
location = 'Masjid'

if location == 'Masjid':
    print('eat')
else:
    print('pray')
# Out:
# eat

# %%
location = 'Masjid'

if location == 'restaurant':
    print('eat')
elif location == 'bank':
    print('money')
elif location == 'bakery':
    print('eggs')
else:
    print('pray')
# Out:
# pray

# %%
location = 'bank'

if location == 'restaurant':
    print('eat')
elif location == 'bank':
    print('money')
elif location == 'bakery':
    print('eggs')
else:
    print('pray')
# Out:
# money

# %%
location = 'garden'

if location == 'restaurant':
    print('eat')
elif location == 'bank':
    print('money')
elif location == 'bakery':
    print('eggs')
else:
    print('go back home')
# Out:
# go back home

# %%
# loops
mylist = [1,2,3,4,5,6,7]

# %%
for num in mylist:
    print('num')
# Out:
# num
# num
# num
# num
# num
# num
# num

# %%
for num in mylist:
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for num in mylist:
    if num % 2 == 0:
        print(num)
# Out:
# 2
# 4
# 6

# %%
for num in mylist:
    if num % 2 == 0:
        print(num)
    else:
        print(f'odd number: {num}')
# Out:
# odd number: 1
# 2
# odd number: 3
# 4
# odd number: 5
# 6
# odd number: 7

# %%
list_sum = 0

for num in mylist:
    list_sum = list_sum + num
    
    print(list_sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28

# %%
list_sum = 0

for num in mylist:
    list_sum = list_sum + num
    
print(list_sum)
# Out:
# 28

# %%
mystring = 'islam is religion of peace'

for letter in mystring:
    print(letter)
# Out:
# i
# s
# l
# a
# m
#
# i
# s
#
# r
# e
# l
# i
# g
# i
# o
# n
#
# o
# f
#
# p
# e
# a
# c
# e

# %%
mytuple = (3,4,5)

for item in mytuple:
    print(item)
# Out:
# 3
# 4
# 5

# %%
second_list = [(3,5),(1,2),(9,8),(4,6)]

# %%
len(second_list)
# Out:
# 4

# %%
for items in second_list:
    print(items)
# Out:
# (3, 5)
# (1, 2)
# (9, 8)
# (4, 6)

# %%
for (a,b) in second_list:
    print(a,b)
# Out:
# 3 5
# 1 2
# 9 8
# 4 6

# %%
for (a,b) in second_list:
    print(a)
    print(b)
# Out:
# 3
# 5
# 1
# 2
# 9
# 8
# 4
# 6

# %%
for (a,b) in second_list:
    print(a)
# Out:
# 3
# 1
# 9
# 4

# %%
mydict = {'k1':2,'k2':3,'k3':4}

for values in mydict:
    print(values)
# Out:
# k1
# k2
# k3

# %%
mydict = {'k1':2,'k2':3,'k3':4}

for values in mydict.items():
    print(values)
# Out:
# ('k1', 2)
# ('k2', 3)
# ('k3', 4)

# %%
mydict = {'k1':2,'k2':3,'k3':4}

for values in mydict.values():
    print(values)
# Out:
# 2
# 3
# 4

# %%
mydict = {'k1':2,'k2':3,'k3':4}

for key,values in mydict.items():
    print(values)
# Out:
# 2
# 3
# 4

# %%
x = 0

while x < 10:
    print(f'current value of x is: {x}')
# Out:
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# current value of x is: 0
# ...

# %%
x = 0

while x < 10:
    print(f'current value of x is: {x}')
    x = x + 1
# Out:
# current value of x is: 0
# current value of x is: 1
# current value of x is: 2
# current value of x is: 3
# current value of x is: 4
# current value of x is: 5
# current value of x is: 6
# current value of x is: 7
# current value of x is: 8
# current value of x is: 9

# %%
x = 0

while x < 10:
    print(f'current value of x is: {x}')
    x = x + 1
else:
    print('x is not more then 10')
# Out:
# current value of x is: 0
# current value of x is: 1
# current value of x is: 2
# current value of x is: 3
# current value of x is: 4
# current value of x is: 5
# current value of x is: 6
# current value of x is: 7
# current value of x is: 8
# current value of x is: 9
# x is not more then 10

# %%
x = 50

while x < 10:
    print(f'current value of x is: {x}')
    x = x + 1
else:
    print('x is not more then 10')
# Out:
# x is not more then 10

# %%
string2 = 'abcdefghij'

# %%
for letter in string2:
    print(letter)
# Out:
# a
# b
# c
# d
# e
# f
# g
# h
# i
# j

# %%
for letter in string2:
    if letter == 'f':
        break
    print(letter)
# Out:
# a
# b
# c
# d
# e

# %%
for letter in string2:
    if letter == 'c':
        break
    print(letter)
# Out:
# a
# b

# %%
# comprehensions
mystring = 'Islam'

# %%
mylist = []

for letter in mystring:
    mylist.append(letter)

# %%
mylist
# Out:
# ['I', 's', 'l', 'a', 'm']

# %%
mylist = [letter for letter in mystring]

# %%
mylist
# Out:
# ['I', 's', 'l', 'a', 'm']

# %%
list1 = [x for x in 'pakistan']

# %%
list1
# Out:
# ['p', 'a', 'k', 'i', 's', 't', 'a', 'n']

# %%
mynum = [a for a in range(0,5)]

# %%
mynum
# Out:
# [0, 1, 2, 3, 4]

# %%
mynum1 = [a**2 for a in range(0,5)]

# %%
mynum1
# Out:
# [0, 1, 4, 9, 16]

# %%
mynum2 = [b**2 for b in range(0,5) if b%2 == 0]

# %%
mynum2
# Out:
# [0, 4, 16]

# %%
mynum1 = [c for c in range(0,10) if c%3 == 0]

# %%
mynum1
# Out:
# [0, 3, 6, 9]

# %%
mynum3 = [c for c in range(0,10) if c%2 == 0]

# %%
mynum3
# Out:
# [0, 2, 4, 6, 8]

# %%
# I-O Files
# %%writefile myfile.txt
I am Abdul.Hadi
I am 1 year old baby
I will become a doctor
# Out:
# Overwriting myfile.txt

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'I am Abdul.Hadi\nI am 1 year old baby\nI will become a doctor\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0) #curser reset
# Out:
# 0

# %%
myfile.read()
# Out:
# 'I am Abdul.Hadi\nI am 1 year old baby\nI will become a doctor\n'

# %%
myfile.readline()
# Out:
# ''

# %%
myfile.seek(0) #curser reset
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['I am Abdul.Hadi\n', 'I am 1 year old baby\n', 'I will become a doctor\n']

# %%
pwd
# Out:
# 'C:\\Users\\Dell'
